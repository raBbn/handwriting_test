# %% [markdown]
# <a href="https://colab.research.google.com/github/raBbn/handwriting_test/blob/master/OCR_and_image_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr-nep
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-nep tesseract-ocr-osd
# 0 upgraded, 4 newly installed, 0 to remove and 35 not upgraded.
# Need to get 5,273 kB of archives.
# After this operation, 16.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pytesseract
try:
  from PIL import Image
except ImportError:
  import Image

# %%
filename = '1.PNG'
img = Image.open(filename)
custom_config = ' --oem 3 --psm 6'
extractedText = pytesseract.image_to_string(img, lang = 'nep', config = custom_config)
print(extractedText)
# Out:
# नयाँ नयाँ जीत अनेक जोड्दै
# , यो देशको इज्जत मान थप्दै
# ८ )नेपाल ज्यामी, सिपाही र किसान सारा
# छन्‌ आज हाम्रा बलियो सहारा।
# नेपाल प्यारो र पवित्र देश
# सौन्दर्य धारा बहने अशेष। यो देशको सिर्जनाको निमित्त
# सङ्गीतको मूल फुटी विशाल पुर्खाहरूको पसिना र रक्त
# छल्की रहे झैँ लयबदय छाल। हाम्रो बहेको छ नसा नासामा
# डोर्याउँदै स्वर्ग छुने दिशामा।
# पाना खुला पर्वत पत्रपत्र ठ्ठ
# छन्‌ वर्ण झैँ वृक्ष लता विचित्र विपत्ति पर्दा पनि हाँसीहाँसी
# खोला चराको ध्वनि गुह्य मन्त्र तयार भैँ चढ्न समेत फाँसी
# नेपाल सङ्गै बहुमूल्य तन्त्र। बाचे बचाए र रमे रमाए
# सङ्घर्षले यो मुलुकै जगाए।

# %%
filename = 'download.png'
img = Image.open(filename)
custom_config = ' --oem 3 --psm 6'
extractedText = pytesseract.image_to_string(img, lang = 'eng', config = custom_config)
print(extractedText)
# Out:
# 1 come running
#
# at your smallest call
# but if need you,
#
# you don't come a all
# ‘forfeit sleep to
#
# make sure you're okay
# but you won't make time
# for me any day
#
# we talk when you want,
# then 'm ignored
#
# ''m left wondering
#
# if you just got bored
# you push me away
# knowing I'l reappear
# but one of these days,
# {just wont't be here.

# %%
import cv2
img = cv2.imread('lastofus.jpg')
plt.imshow(img)

# %%
# grayscale
def get_grayscale(image):
  return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
img_gray = get_grayscale(img)
plt.imshow(img_gray)

# %%
#noise removal
def remove_noise(image):
  return cv2.medianBlur(image, 9)

# %%
img_noise = remove_noise(img)
plt.imshow(img_noise)

# %%
#dilation
def dilation(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.dilate(image, kernel, iterations = 1)

# %%
img_dilate = dilation(img_gray)
plt.imshow(img_noise)

# %%
#eroison
def erosion(image):
  kernel = np.ones((5,5), np.uint8)
  return cv2.erode(image, kernel, iterations = 2)

# %%
img_erode = erosion(img_gray)
plt.imshow(img_noise)
